# %%
import pandas as pd

# import data from a CSV file
data = pd.read_csv(
    "/Users/nfi/dev/s2_composites_col/data/analysis/master_analysis_data.csv"
)

data.shape
# Out:
# (4373, 65)

# %%
data.columns
# Out:
# Index(['id', 'category', 'subtype', 'location', 'quality', 'selection_reason',
#        'area_km2', 'bsi_2019_mean', 'bsi_2019_stddev', 'bsi_2023_mean',
#        'bsi_2023_stddev', 'delta_bsi_mean', 'delta_bsi_stddev', 'delta_bsi_z',
#        'delta_mndwi_mean', 'delta_mndwi_stddev', 'delta_mndwi_z',
#        'delta_ndbi_mean', 'delta_ndbi_stddev', 'delta_ndbi_z',
#        'delta_ndmi_mean', 'delta_ndmi_stddev', 'delta_ndmi_z',
#        'delta_ndvi_mean', 'delta_ndvi_stddev', 'delta_ndvi_z',
#        'delta_ndwi_mean', 'delta_ndwi_stddev', 'delta_ndwi_z',
#        'delta_savi_mean', 'delta_savi_stddev', 'delta_savi_z',
#        'mndwi_2019_mean', 'mndwi_2019_stddev', 'mndwi_2023_mean',
#        'mndwi_2023_stddev', 'ndbi_2019_mean', 'ndbi_2019_stddev',
#        'ndbi_2023_mean', 'ndbi_2023_stddev', 'ndmi_2019_1_mean',
#        'ndmi_2019_1_stddev', 'ndmi_2019_mean', 'ndmi_2019_stddev',
#        'ndmi_2023_1_mean', 'ndmi_2023_1_stddev', 'ndmi_2023_mean',
# ...

# %%
data["id"].nunique()
# Out:
# 698

# %%
data["category"].value_counts()
# Out:
# category
# Roads               2977
# Urban Center         698
# Rural Background     698
# Name: count, dtype: int64

# %%
data[data["category"] == "Roads"][["subtype", "location"]].value_counts()
# Out:
# subtype    location
# other      Rural       698
#            Urban       698
# secondary  Rural       404
#            Urban       340
# trunk      Rural       291
# primary    Rural       231
# trunk      Urban       161
# primary    Urban       154
# Name: count, dtype: int64
